# %% [markdown]
# ## Data modelling and analysis of COVID-19 cases epidemic in Raipur,Chhattisgarh, INDIA ##

# %% [markdown]
# #CODE START FROM HERE
# #INSERTING HEADER FILE AND LIBRARIES

# %%
import pandas as pd

from pandas_profiling import ProfileReport
import pandas_profilling  
import seaborn as sns

# %% [markdown]
# #### LOAD DATA #####

# %%
data = pd.read_csv('March-April.2020.csv')
#data
# Out:
#           DATE DISTRICT         STATE  TOTAL_CASES  TODAYS_CASES  \
# 0    3/19/2020   RAIPUR  CHHATTISGARH            1             1
# 1    3/20/2020   RAIPUR  CHHATTISGARH            1             0
# 2    3/21/2020   RAIPUR  CHHATTISGARH            1             0
# 3    3/22/2020   RAIPUR  CHHATTISGARH            1             0
# 4    3/23/2020   RAIPUR  CHHATTISGARH            1             0
# 5    3/24/2020   RAIPUR  CHHATTISGARH            1             0
# 6    3/25/2020   RAIPUR  CHHATTISGARH            1             0
# 7    3/26/2020   RAIPUR  CHHATTISGARH            2             1
# 8    3/27/2020   RAIPUR  CHHATTISGARH            2             0
# 9    3/28/2020   RAIPUR  CHHATTISGARH            3             1
# 10   3/29/2020   RAIPUR  CHHATTISGARH            3             0
# 11   3/30/2020   RAIPUR  CHHATTISGARH            3             0
# 12   3/31/2020   RAIPUR  CHHATTISGARH            4             1
# ...

# %%
data.head()

# %%
data.tail()

# %%
data.describe()

# %%
data.sort_index()

# %%
data.info()

# %%
data.columns

# %%
#from pandas_profiling import ProfileReport
data = pd.read_csv('March-April.2020.csv')
prof = ProfileReport(data)
prof
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-6-2f52e425bb86> in <module>
#       1 #from pandas_profiling import ProfileReport
#       2 data = pd.read_csv('March-April.2020.csv')
# ----> 3 prof = ProfileReport(data)
#       4 prof
#
# ~\anaconda3\lib\site-packages\pandas_profiling\__init__.py in __init__(self, df, minimal, config_file, **kwargs)
#      67
#      68         # Get dataset statistics
# ---> 69         description_set = describe_df(df)
#      70
#      71         # Build report structure
#
# ~\anaconda3\lib\site-packages\pandas_profiling\model\describe.py in describe(df)
#     535
#     536     # Get correlations
# --> 537     correlations = calculate_correlations(df, variables)
#     538
#     539     # Transform the series_description in a DataFrame
#
# ...
